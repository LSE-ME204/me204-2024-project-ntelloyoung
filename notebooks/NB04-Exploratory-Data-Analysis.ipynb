# %%
import pandas as pd

# import ggplot with letsplot
from lets_plot import *

import sqlite3

LetsPlot.setup_html()
# Out:
#             <div id="DfRZLq"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.3.3/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("DfRZLq").appendChild(div);
#                     };
#                     var e = document.getElementById("DfRZLq");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
# Creating variables to call each dataframe 'MobyGames.db'
conn = sqlite3.connect('../data/MobyGames.db')

query_games = "SELECT * FROM all_games"
all_games = pd.read_sql_query(query_games, conn)

query_genre = "SELECT * FROM genre_info"
genre_info = pd.read_sql_query(query_genre, conn)

query_release = "SELECT * FROM release_info"
release_info = pd.read_sql_query(query_release, conn)

query_score = "SELECT * FROM score_info"
score_info = pd.read_sql_query(query_score, conn)

# %% [markdown]
# All plot analysis is done in [Index.mb](../docs/index.md)

# %% [markdown]
# ## Plot 1 - Games per Genre

# %%
# Split the 'Genre' column by commas and explode it to create a row for each genre
plot1_df = genre_info.assign(Genre=genre_info.Genre.str.split(',')).explode('Genre')

# Remove leading and trailing white spaces from the exploded 'Genre' column
plot1_df['Genre'] = plot1_df['Genre'].str.strip()

# %%
count_of_genres = (
    ggplot(data=plot1_df, 
           mapping=aes(x='Genre', fill='Genre')) + 
    geom_bar(alpha=0.5) +
    labs(title='Distribution of Game Genres',
         subtitle='Number of games in each genre for the first Xbox',
         x='Genre',
         y='Number of games') +
    theme_minimal() +
    theme(legend_position='none')
)
count_of_genres
# Out:
#    <div id="1xBqqU"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# },
# "mapping":{
# "x":"Genre",
# "fill":"Genre"
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Distribution of Game Genres",
# "subtitle":"Number of games in each genre for the first Xbox"
# },
# "theme":{
# "name":"minimal",
# "legend_position":"none"
# },
# "kind":"plot",
# "scales":[{
# "name":"Genre",
# "aesthetic":"x"
# },{
# "name":"Number of games",
# "aesthetic":"y"
# }],
# "layers":[{
# "geom":"bar",
# "mapping":{
# },
# "data_meta":{
# },
# "alpha":0.5,
# "data":{
# "..count..":[544.0,166.0,37.0,41.0,260.0,54.0,77.0,17.0,16.0,8.0,20.0,2.0],
# "Genre":["Action","Racing / Driving","Role-playing (RPG)","Compilation","Sports","Strategy / tactics","Simulation","Adventure","Puzzle","Gambling","Special edition","Educational"]
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("1xBqqU");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# Saves the plot
ggsave(count_of_genres, '../docs/figures/genre_distribution.svg', path='.', iframe=False)
# Out:
# '/Users/nicolas/me204-2024-project-ntelloyoung/me204-2024-project-ntelloyoung/docs/figures/genre_distribution.svg'

# %% [markdown]
# The figure above shows us the most popular genres for the xbox

# %% [markdown]
# ## Plot 2 - Average Score per Genre

# %%
# Joins the 'plot1_df' and 'score_info' dataframes on the 'title' column
plot2_df = plot1_df.merge(score_info, on='title')

# Group by 'Genre' and calulate the average score for each genre
plot2_df = plot2_df.groupby('Genre').agg({'average_score':'mean'}).reset_index()

# Sort the dataframe by 'average_score' in descending order
plot2_df = plot2_df.sort_values(by='average_score', ascending=False)

average_score_per_genre = (
    ggplot(data=plot2_df, mapping=aes(x='Genre', y='average_score', fill='Genre')) +
    geom_bar(stat='identity', alpha=0.75) +
    labs(title='Average score per genre', x='Genre', y='Average score') +
    ylim(60, 80) +
    theme_minimal() +
    theme(legend_position='none')
)
average_score_per_genre
# Out:
#    <div id="Iug3aL"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "Genre":["Adventure","Special edition","Simulation","Role-playing (RPG)","Compilation","Sports","Strategy / tactics","Racing / Driving","Educational","Puzzle","Action","Gambling"],
# "average_score":[74.2775,73.25818181818182,72.17857142857143,71.952,71.6153125,71.03429149797572,70.0034,69.24676829268293,68.83500000000001,68.04785714285714,67.85923220973783,65.24]
# },
# "mapping":{
# "x":"Genre",
# "y":"average_score",
# "fill":"Genre"
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Average score per genre"
# },
# "theme":{
# "name":"minimal",
# "legend_position":"none"
# },
# "kind":"plot",
# "scales":[{
# "name":"Genre",
# "aesthetic":"x"
# },{
# "name":"Average score",
# "aesthetic":"y"
# },{
# "aesthetic":"y",
# "limits":[60.0,80.0]
# }],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "alpha":0.75,
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("Iug3aL");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
ggsave(average_score_per_genre, '../docs/figures/average_score_per_genre.svg', path='.', iframe=False)
# Out:
# '/Users/nicolas/me204-2024-project-ntelloyoung/me204-2024-project-ntelloyoung/docs/figures/average_score_per_genre.svg'

# %% [markdown]
# The figure above shows us the most successful genres for the xbox

# %% [markdown]
# ## Plot 3 - Number of Games Released per Developer

# %%
# Some entries in 'developes' have multiple values in them, each developer is enclosed with '' when there is more than one. This creates a new row for each developer
plot3_df = release_info.assign(developers=release_info.developers.str.split("',")).explode('developers')

# Strip all the white spaces from the 'Perspective' column again and convert to lowercase
plot3_df['developers'] = plot3_df['developers'].str.strip().str.lower()

# Create a table showing how many games each developer has released
plot3_df = plot3_df.groupby('developers').agg({'title':'count'}).reset_index()
plot3_df = plot3_df.sort_values(by='title', ascending=False)

# %%
# Create a visual showing how many games each developer has released, no x axis
games_per_developer = (
    ggplot(data=plot3_df.head(20), mapping=aes(x='developers', y='title', fill='developers')) +
    geom_bar(stat='identity', alpha=0.75) +
    labs(title='Number of games per developer', x='Developer', y='Number of games') +
    theme_minimal() +
    theme(axis_text_x=element_blank()) +
    ggsize(700, 600) 
)
games_per_developer
# Out:
#    <div id="XyoQnc"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "developers":["'electronic arts canada'","'ea tiburon'","'high voltage software, inc.'","'visual concepts entertainment, inc.'","'midway games, inc.'","'electronic arts canada","'codemasters software company limited, the'","'kush games, inc.'","'ubisoft entertainment inc.'","'radical entertainment inc.'","'eurocom developments ltd'","'treyarch corporation'","'blitz games ltd'","'blade interactive studios ltd.'","'acclaim studios austin'","'hypnotix, inc.'","'eutechnyx limited'","'climax (brighton) ltd'","'fun labs romania s.r.l.'","'sand grain studios"],
# "title":[31.0,19.0,12.0,12.0,12.0,11.0,11.0,10.0,9.0,9.0,8.0,8.0,7.0,7.0,7.0,7.0,6.0,6.0,6.0,6.0]
# },
# "mapping":{
# "x":"developers",
# "y":"title",
# "fill":"developers"
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Number of games per developer"
# },
# "theme":{
# "name":"minimal",
# "axis_text_x":{
# "blank":true
# }
# },
# "ggsize":{
# "width":700.0,
# "height":600.0
# },
# "kind":"plot",
# "scales":[{
# "name":"Developer",
# "aesthetic":"x"
# },{
# "name":"Number of games",
# "aesthetic":"y"
# }],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "alpha":0.75,
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("XyoQnc");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
ggsave(games_per_developer, '../docs/figures/games_per_developer.svg', path='.', iframe=False)
# Out:
# '/Users/nicolas/me204-2024-project-ntelloyoung/me204-2024-project-ntelloyoung/docs/figures/games_per_developer.svg'

# %% [markdown]
# Shows us the number of gmaes for the top 20 xbox developers

# %% [markdown]
# ## Plot 4 - Average Score per Game and Number of People Who Worked on Them

# %%
# Create a table for the average score per game and the credits of the game
plot4_df = score_info.merge(release_info, on='title')
plot4_df = plot4_df.groupby('title').agg({'average_score':'mean', 'credits':'sum', 'xbox_score':'sum'}).reset_index()
plot4_df = plot4_df.sort_values(by='average_score', ascending=False)

# %%
score_per_game_and_workers = (
    ggplot(plot4_df, aes(x='credits', y='average_score', color='xbox_score', label='title')) +
    geom_point(size=3) +
    geom_smooth(method='lm', se=False, linetype='dashed', color='blue') +
    labs(
        title='Average score per game and credits',
        subtitle='Average score of the game and the number of people who worked on it',
        x='Number of people who worked on the game',
        y='Average score',
        color='Xbox score'
    ) +
    theme_minimal() +
    theme(
        plot_title=element_text(hjust=0.5),
        plot_subtitle=element_text(hjust=0.5)
    )
)
score_per_game_and_workers
# Out:
#    <div id="PEAWtW"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "average_score":[96.0,93.5,92.0,90.0,90.0,89.33,88.33,88.0,88.0,87.33,86.33,86.33,86.33,86.0,85.67,85.67,85.67,85.33,85.33,85.33,85.0,85.0,85.0,85.0,85.0,84.67,84.67,84.67,84.67,84.67,84.33,84.33,84.33,84.33,84.0,84.0,84.0,83.67,83.5,83.33,83.33,83.33,83.33,83.33,83.0,83.0,83.0,83.0,83.0,83.0,82.67,82.67,82.67,82.67,82.67,82.33,82.33,82.33,82.33,82.33,82.0,82.0,82.0,82.0,82.0,82.0,82.0,82.0,82.0,81.67,81.67,81.67,81.67,81.67,81.67,81.67,81.67,81.33,81.33,81.33,81.33,81.33,81.33,81.0,81.0,81.0,81.0,81.0,81.0,81.0,81.0,80.67,80.67,80.67,80.67,80.67,80.5,80.33,80.33,80.33,80.33,80.33,80.33,80.33,80.33,80.33,80.33,80.33,80.33,80.33,80.0,80.0,80.0,80.0,80.0,80.0,80.0,80.0,80.0,80.0,80.0,80.0,80.0,80.0,79.67,79.67,79.67,79.67,79.67,79.67,79.67,79.67,79.67,79.67,79.67,79.67,79.33,79.33,79.33,79.33,79.33,79.33,79.33,79.33,79.33,79.33,79.33,79.33,79.33,79.33,79.33,79.33,79.0,79.0,79.0,79.0,79.0,79.0,79.0,79.0,78.67,78.67,78.67,78.33,78.33,78.33,78.33,78.33,78.33,78.33,78.33,78.33,78.33,78.0,78.0,78.0,78.0,78.0,78.0,78.0,78.0,78.0,78.0,78.0,78.0,77.67,77.67,77.67,77.67,77.67,77.67,77.67,77.67,77.67,77.67,77.67,77.67,77.33,77.33,77.33,77.33,77.33,77.33,77.33,77.33,77.33,77.33,77.0,77.0,77.0,77.0,77.0,77.0,77.0,77.0,77.0,77.0,77.0,77.0,77.0,77.0,77.0,77.0,77.0,76.67,76.67,76.67,76.67,76.67,76.67,76.67,76.67,76.67,76.67,76.67,76.67,76.67,76.67,76.5,76.33,76.33,76.33,76.33,76.33,76.33,76.33,76.33,76.33,76.33,76.33,76.33,76.0,76.0,76.0,76.0,76.0,76.0,76.0,76.0,76.0,76.0,76.0,76.0,76.0,76.0,76.0,76.0,75.67,75.67,75.67,75.67,75.67,75.67,75.67,75.67,75.67,75.5,75.5,75.33,75.33,75.33,75.33,75.33,75.33,75.33,75.33,75.33,75.33,75.33,75.33,75.33,75.33,75.33,75.33,75.33,75.33,75.33,75.33,75.33,75.0,75.0,75.0,75.0,75.0,75.0,75.0,75.0,75.0,75.0,75.0,75.0,75.0,74.67,74.67,74.67,74.67,74.67,74.67,74.67,74.67,74.67,74.67,74.67,74.67,74.67,74.67,74.67,74.67,74.67,74.5,74.5,74.33,74.33,74.33,74.33,74.33,74.33,74.33,74.33,74.33,74.0,74.0,74.0,74.0,74.0,74.0,74.0,74.0,74.0,74.0,74.0,74.0,74.0,74.0,74.0,74.0,73.67,73.67,73.67,73.67,73.67,73.67,73.67,73.67,73.67,73.67,73.67,73.5,73.5,73.5,73.33,73.33,73.33,73.33,73.33,73.33,73.33,73.33,73.33,73.33,73.33,73.33,73.33,73
,561.0,652.0,300.0,76.0,178.0,333.0,352.0,147.0,93.0,180.0,290.0,172.0,200.0,625.0,328.0,94.0,311.0,143.0,37.0,0.0,644.0,19.0,248.0,165.0,137.0,137.0,666.0,163.0,358.0,261.0,69.0,193.0,172.0,214.0,472.0,354.0,244.0,104.0,220.0,65.0,88.0,99.0,42.0,204.0,190.0,130.0,351.0,27.0,197.0,22.0,175.0,588.0,225.0,262.0,433.0,207.0,67.0,27.0,98.0,249.0,116.0,89.0,52.0,363.0,332.0,576.0,154.0,179.0,447.0,397.0,142.0,435.0,408.0,202.0,153.0,110.0,90.0,118.0,133.0,282.0,175.0,130.0,83.0,137.0,299.0,159.0,68.0,527.0,62.0,67.0,92.0,252.0,0.0,16.0,56.0,179.0,395.0,106.0,64.0,147.0,305.0,167.0,271.0,81.0,81.0,250.0,486.0,488.0,228.0,13.0,313.0,278.0,174.0,145.0,22.0,178.0,407.0,104.0,346.0,131.0,302.0,94.0,326.0,298.0,189.0,84.0,87.0,58.0,235.0,118.0,94.0,228.0,149.0,380.0,0.0,275.0,63.0,78.0,78.0,240.0,166.0,493.0,312.0,96.0,328.0,122.0,95.0,84.0,742.0,0.0,169.0,0.0,112.0,639.0,75.0,98.0,276.0

# %%
# Save the plot as an image
ggsave(score_per_game_and_workers, '../docs/figures/score_per_game_and_workers.svg', path='.', iframe=False)
# Out:
# '/Users/nicolas/me204-2024-project-ntelloyoung/me204-2024-project-ntelloyoung/docs/figures/score_per_game_and_workers.svg'

# %% [markdown]
# Shows the relationship between game score and the number of people who worked on the game

# %% [markdown]
# ## Plot 5 - Comparing three different scores, 'moby_score', 'player_score', and 'critics_score'

# %%
# Create a table for the average score per game and the credits of the game
plot5_df = score_info.merge(release_info, on='title')
plot5_df = plot5_df.groupby('title').agg({'moby_score':'mean', 'player_score':'mean', 'critics_score':'mean'}).reset_index()
plot5_df = plot5_df.sort_values(by='moby_score', ascending=False)
#drop the title column
plot5_df = plot5_df.drop('title', axis=1)

# %%
# Reshape the dataframe to long format so that the scores are in one column and the score type is in another
plot5_df_long = pd.melt(plot5_df, var_name='score_type', value_name='score')

# Create the plot
score_distribution = (
    ggplot(data=plot5_df_long, mapping=aes(x='score', fill='score_type')) +
    geom_density(alpha=0.7) +
    scale_fill_manual(values={'moby_score': 'lightblue', 'player_score': 'red', 'critics_score': 'green'}) +
    labs(title='Distribution of scores', x='Score', y='Density', fill='Score Type') +
    theme_minimal()     +
    ggsize(900, 400) 
)

# %%
ggsave(score_distribution, '../docs/figures/score_distribution.svg', path='.', iframe=False)
# Out:
# '/Users/nicolas/me204-2024-project-ntelloyoung/me204-2024-project-ntelloyoung/docs/figures/score_distribution.svg'

# %% [markdown]
# Shows the distribution of scores for each score giver, 'moby_score', 'critics_score', and 'player_score'
